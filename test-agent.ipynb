# %% [markdown]
# # Agent call

# %%
# import subprocess

#server_proc = subprocess.Popen(
#    ["python3", "mcp_server.py"],
#    stdout=subprocess.PIPE,
#    stderr=subprocess.PIPE
#)

# %%
from hr_agent import HRAgent, AgentConfig
import asyncio

agent = HRAgent(AgentConfig(debug=False, max_steps=9, mcp_endpoint="http://127.0.0.1:8000/sse",model_name="llama3.1"))
# Out:
# [AGENT] initialize() called and Agent is Ready!

# %%
import sys
print(sys.version)
# Out:
# 3.12.4 (main, Jun  6 2024, 18:26:44) [Clang 15.0.0 (clang-1500.3.9.4)]

# %%
await agent.run("What is my leave balance for EMP001?")
# Out:
# 'Your leave balance for EMP001 is 25 annual leave days, 10 sick leave days, and 5 parental leave days.'

# %%
await agent.run("Show my full profile for EMP001", False)
# Out:
# 'Full profile for EMP001:\n\nEmployee Code: EMP001\nName: Osama Oransa\nSex: Male\nBirthdate: 1990-05-01\nNationality: Egyptian\nMarital Status: Single\nManager Code: MGR001\nCreated At: 2026-06-05T11:06:02.924677\nUpdated At: 2026-06-05T11:06:02.924677\n\nContacts:\nID: 1\nEmployee Code: EMP001\nContact Type: email\nValue: osama@example.com\nIs Primary: true\nCreated At: 2026-06-05T11:06:02.927362\n\nID: 2\nEmployee Code: EMP001\nContact Type: phone\nValue: +201234567890\nIs Primary: true\nCreated At: 2026-06-05T11:06:02.927364\n\nEmployment:\nEmployee Code: EMP001\nHire Date: 2023-01-01\nLast Working Date: null\nTitle: Software Engineer\nDepartment: Engineering\nEmployment Type: full-time\nEmployment Status: active\nLocation: Cairo\n\nLeave Balance:\nEmployee Code: EMP001\nAnnual Leave Days: 25\nSick Leave Days: 10\nParental Leave Days: 5\nLast Updated: 2026-06-05T14:57:45.159378\n\nCompensation:\nID: 1\nEmployee Code: EMP001\nBase Salary: $3000.00\nCurrency: USD\nAllowance: $500.00\nEffective From: 2024-01-01\nCreated At: 2026-06-05T11:06:02.936015'

# %%
await agent.run("Show details of my leave requests for EMP001")
# Out:
# 'You have the following leave requests:\n\n* Request 3: Pending from 2026-07-01 to 2026-07-05.\n* Request 5: Pending from 2026-08-11 to 2026-08-15, delegated to MGR001.\n* Request 1: Rejected from 2024-06-10 to 2024-06-15, delegate was EMP002 and comment was "Family vacation".\n* Request 6: Pending from 2026-08-11 to 2026-08-15, delegated to MGR001.\n* Request 4: Approved from 2026-08-11 to 2026-08-15, delegate was MGR001 and approved by MGR001 on 2026-06-05T14:57:45.160999.\n* Request 10: Pending from 2026-09-01 to 2026-09-05.\n* Request 12: Pending from 2026-06-20 to 2026-06-24, delegate was EMP001.'

# %%
await agent.run("Show me the status on my last leave requests for EMP001")
# Out:
# "Employee EMP001 has the following leave requests:\n1. Pending leave request for 2026-07-01 to 2026-07-05\n2. Pending leave request for 2026-08-11 to 2026-08-15 with delegate MGR001\n3. Rejected leave request for 2024-06-10 to 2024-06-15 with manager comment 'Approved!'\n4. Approved leave request for 2026-08-11 to 2026-08-15\n5. Pending leave request for 2026-09-01 to 2026-09-05\n6. Pending leave request for 2026-06-20 to 2026-06-24 with delegate EMP001"

# %%
await agent.run("Show me the name of manager and his email only for employee EMP001")
# Out:
# 'The manager of Osama Oransa is Mohamed Mourad (MGR001), and his email can be obtained from the HR system using the employee code MGR001.'

# %%
await agent.run("tell me what information is needed to submit a leave request?")
# Out:
# 'To submit a leave request, you will need the following information: your employee code (EMP001), the type of leave you want to take (e.g., vacation, sick leave), and the start and end dates of your leave.'

# %%
await agent.run("I want to submit leave request for my employee name is Osama Oransa, i want the leave to start from 11-08-2026 till 15-08-2026, my delegate employee name is Mohamed Mourad and leave type is 1")
# Out:
# 'Invalid date format. Please use YYYY-MM-DD for the start and end dates.'

# %%
await agent.run("tell me as a manager what is needed to approve leave request?")
# Out:
# 'To approve a leave request, you need the request ID and your employee code (manager_code).'

# %%
await agent.run("list all the details of leave requests pending on my approval as a manager MG001, list all please not just the count?")
# Out:
# 'There are no leave requests pending for your approval as a manager MG001.'

# %%
await agent.run("i want to reject request number 1 with manager comment Rejected!, my manager code is MG001")
# Out:
# 'Request already processed.'

# %%
await agent.run("Give me my basic salary and allowance")
# Out:
# 'Your basic salary is $3000.00 USD and your allowance is $500.00 USD.'

# %%
await agent.run("Give me the policy that contains info about Hybrid work?")
# Out:
# 'The Remote Work Policy version 1.0, effective as of January 1st, 2024, allows hybrid work depending on manager approval.'
