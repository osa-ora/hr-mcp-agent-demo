# %% [markdown]
# # Agent call

# %%
# import subprocess

#server_proc = subprocess.Popen(
#    ["python3", "mcp_server.py"],
#    stdout=subprocess.PIPE,
#    stderr=subprocess.PIPE
#)

# %%
from hr_agent import HRAgent, AgentConfig
import asyncio

agent = HRAgent(AgentConfig(debug=False))
#agent = HRAgent(AgentConfig(debug=False, max_steps=9, mcp_endpoint="http://127.0.0.1:8000/sse",model_name="llama3.1"))
# Out:
# Will use HR MCP Server at: http://127.0.0.1:8000/sse
# [AGENT] initialize() called and Agent is Ready!

# %%
import sys
print(sys.version)
# Out:
# 3.14.5 (main, May 10 2026, 10:21:34) [Clang 21.0.0 (clang-2100.0.123.102)]

# %%
await agent.run("What is my leave balance for Osama Oransa?")
# Out:
# 'Osama Oransa has an annual leave balance of 0 days, a sick leave balance of 10 days, and a parental leave balance of 5 days, last updated on June 7, 2026.'

# %%
await agent.run("Show my full profile EMP001?", False)
# Out:
# 'Osama Oransa, EMP001, M, Egyptian, single, Software Engineer, Engineering, full-time, active, Cairo.'

# %%
await agent.run("Show details of my leave requests for EMP001")
# Out:
# 'There are 4 leave requests for EMP001. Request IDs: 29, 27, 25 and 18. Statuses are PENDING for IDs 29, 27 and 18 while ID 25 is APPROVED.'

# %%
await agent.run("Show me the status on my last leave requests for EMP001")
# Out:
# 'There are no pending leave requests for the manager CEO001.'

# %%
await agent.run("Show me the name of manager and his email only for employee EMP001")
# Out:
# 'The manager of Osama Oransa is Mohamed Mourad, whose email can be obtained via the employee profile.'

# %%
await agent.run("tell me what information is needed to submit a leave request?")
# Out:
# 'To submit a leave request, you need to provide the employee code (which is EMP001), leave type ID, start date in YYYY-MM-DD format, and end date in YYYY-MM-DD format.'

# %%
await agent.run("I want to submit leave request for my employee name is Osama Oransa, i want the leave to start from 11-08-2026 till 15-08-2026, my delegate employee name is Mohamed Mourad and leave type is 1")
# Out:
# 'You need to accrue more annual leave days or consult the company policies for further guidance.'

# %%
await agent.run("tell me as a manager what is needed to approve leave request?")
# Out:
# 'To approve a leave request, you need the request_id and your manager_code. You can get these by calling the get_pending_requests_for_manager tool with your manager_code.'

# %%
await agent.run("list all the details of leave requests pending on my approval as a manager MG001, list all please not just the count?")
# Out:
# 'There are no leave requests pending for your approval.'

# %%
await agent.run("i want to reject request number 1 with manager comment Rejected!, my manager code is MG001")
# Out:
# 'The request with ID 1 has already been processed and cannot be rejected again.'

# %%
await agent.run("Give me my basic salary and allowance")
# Out:
# 'Your basic salary is $3000.00 and your allowance is $500.00.'

# %%
await agent.run("Give me the policy that contains info about Hybrid work?", True)
# Out:
# [DEBUG] Starting MCP session...
#
# KNOWN CONTEXT:
# employee_name: Osama Oransa
# employee_code: EMP001
#
#
# ================ STEP 1 ================
#
# [RAW LLM OUTPUT]
# {
#   "action": "tool",
#   "tool_name": "search_policies",
#   "arguments": {
#     "keyword": "Hybrid work"
#   }
# }
# [PARSED DECISION]
# {'action': 'tool', 'tool_name': 'search_policies', 'arguments': {'keyword': 'Hybrid work'}}
# [TOOL CALL] search_policies
# [ARGS] {'keyword': 'Hybrid work'}
# [TOOL OUTPUT]
# [{'id': 2, 'policy_name': 'Remote Work Policy', 'category': 'Work', 'content': 'Hybrid work allowed depending on manager approval.', 'version': '1.0', 'effective_date': '2024-01-01'}]
#
# ================ STEP 2 ================
#
# [RAW LLM OUTPUT]
# {
#   "action": "final",
#   "answer": "The Remote Work Policy allows Hybrid work depending on manager approval, effective from January 1st, 2024."
# }
# [PARSED DECISION]
# {'action': 'final', 'answer': 'The Remote Work Policy allows Hybrid work depending on manager approval, effective from January 1st, 2024.'}
# 'The Remote Work Policy allows Hybrid work depending on manager approval, effective from January 1st, 2024.'
